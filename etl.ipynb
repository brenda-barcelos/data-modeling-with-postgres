# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('data/song_data')

# %%
filepath = song_files[0]

# %%
print(filepath)
# Out:
# /home/brenda/Udacity/data-modeling-with-postgres/data/song_data/A/B/B/TRABBAM128F429D223.json

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARBGXIG122988F409D         37.77916        -122.42005
#
#    artist_location artist_name             song_id              title  \
# 0  California - SF  Steel Rain  SOOJPRH12A8C141995  Loaded Like A Gun
#
#     duration  year
# 0  173.19138     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','artist_id','year','duration']].values.tolist()[0]
song_data
# Out:
# ['SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, 173.19138]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute('truncate dim_song;')
cur.execute(song_table_insert, song_data)
cur.execute('select * from dim_song')
row = cur.fetchone()
while row:
   print(row)
   row = cur.fetchone()
conn.commit()
# Out:
# ('SOOJPRH12A8C141995', 'Loaded Like A Gun', 'ARBGXIG122988F409D', 0, Decimal('173.19138'))

# %%
#cur.close()
#conn.close()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']].values.tolist()[0]
artist_data
# Out:
# ['ARBGXIG122988F409D', 'Steel Rain', 'California - SF', 37.77916, -122.42005]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
#conn.rollback()
#cur.execute('truncate dim_artist;')
cur.execute(artist_table_insert, artist_data)
cur.execute('select * from dim_artist')
row = cur.fetchone()
while row:
   print(row)
   row = cur.fetchone()
conn.commit()
# Out:
# ('ARBGXIG122988F409D', 'Steel Rain', 'California - SF', Decimal('37.77916'), Decimal('-122.42005'))

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines = True)
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 1                       None  Logged In   Stefany      F              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 1     White        NaN  free               Lubbock, TX    GET      Home
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# 0  1541033612796        184         Am I High (Feat. Malice)     200
# 1  1540708070796         82                             None     200
# 2  1540708070796         82  A Lack Of Color (Album Version)     200
# 3  1540708070796         82                    I Have A Wish     200
# 4  1540006905796        153          Monster (Album Version)     200
#
#               ts                                          userAgent  userId
# 0  1541121934796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101
# 1  1541122176796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 2  1541122241796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 3  1541122457796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 4  1541126568796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      66

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df[df['page'] =='NextSong']
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
# 5          Dance Gavin Dance  Logged In    Marina      F              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
# 5    Sutton  218.46159  free               Salinas, CA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# 0  1541033612796        184         Am I High (Feat. Malice)     200
# 2  1540708070796         82  A Lack Of Color (Album Version)     200
# 3  1540708070796         82                    I Have A Wish     200
# 4  1540006905796        153          Monster (Album Version)     200
# 5  1541064343796         47     Uneasy Hearts Weigh The Most     200
#
#               ts                                          userAgent  userId
# 0  1541121934796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101
# 2  1541122241796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 3  1541122457796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      83
# 4  1541126568796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      66
# 5  1541127957796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      48

# %%
df2 = df[df['artist'] == 'Weezer']
df2.head()
# Out:
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []

# %%
t = df['ts']
print(t)
#t.head()
# Out:
# 0      1541121934796
# 2      1541122241796
# 3      1541122457796
# 4      1541126568796
# 5      1541127957796
#            ...
# 166    1541184339796
# 167    1541187675796
# 168    1541191023796
# 169    1541191251796
# 170    1541191397796
# Name: ts, Length: 155, dtype: int64

# %%
t = df
t['ts'] = pd.to_datetime(t['ts'], unit = 'ms')
t.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
# 5          Dance Gavin Dance  Logged In    Marina      F              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
# 5    Sutton  218.46159  free               Salinas, CA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# 0  1541033612796        184         Am I High (Feat. Malice)     200
# 2  1540708070796         82  A Lack Of Color (Album Version)     200
# 3  1540708070796         82                    I Have A Wish     200
# 4  1540006905796        153          Monster (Album Version)     200
# 5  1541064343796         47     Uneasy Hearts Weigh The Most     200
#
#                        ts                                          userAgent  \
# 0 2018-11-02 01:25:34.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 2 2018-11-02 01:30:41.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3 2018-11-02 01:34:17.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4 2018-11-02 02:42:48.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5 2018-11-02 03:05:57.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#    userId
# 0     101
# 2      83
# 3      83
# 4      66
# 5      48

# %% [markdown]
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
time_data = list([t['ts'], t['ts'].dt.hour, t['ts'].dt.day, t['ts'].dt.isocalendar().week, t['ts'].dt.month, t['ts'].dt.year, t['ts'].dt.weekday])
print('time_data data type: ', type(time_data))
print(time_data[3])
column_labels = (['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday'])
print('colum_labels data type: ', type(column_labels))
# Out:
# time_data data type:  <class 'list'>
# 0      44
# 2      44
# 3      44
# 4      44
# 5      44
#        ..
# 166    44
# 167    44
# 168    44
# 169    44
# 170    44
# Name: week, Length: 155, dtype: UInt32
# colum_labels data type:  <class 'list'>

# %%
time_df = dict(zip(column_labels,time_data))
print('time_df data type', type(time_df))
time_df = pd.DataFrame(time_df)
time_df.head()
# Out:
# time_df data type <class 'dict'>
#                start_time  hour  day  week  month  year  weekday
# 0 2018-11-02 01:25:34.796     1    2    44     11  2018        4
# 2 2018-11-02 01:30:41.796     1    2    44     11  2018        4
# 3 2018-11-02 01:34:17.796     1    2    44     11  2018        4
# 4 2018-11-02 02:42:48.796     2    2    44     11  2018        4
# 5 2018-11-02 03:05:57.796     3    2    44     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
#conn.rollback()
for i, row in time_df.iterrows():
    #print(row)
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
df.head()
# Out:
#                       artist       auth firstName gender  itemInSession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
# 5          Dance Gavin Dance  Logged In    Marina      F              0
#
#    lastName     length level                  location method      page  \
# 0       Fox  288.99220  free  New Orleans-Metairie, LA    PUT  NextSong
# 2     White  216.42404  free               Lubbock, TX    PUT  NextSong
# 3     White  221.33506  free               Lubbock, TX    PUT  NextSong
# 4  Arellano  178.02404  free   Harrisburg-Carlisle, PA    PUT  NextSong
# 5    Sutton  218.46159  free               Salinas, CA    PUT  NextSong
#
#     registration  sessionId                             song  status  \
# 0  1541033612796        184         Am I High (Feat. Malice)     200
# 2  1540708070796         82  A Lack Of Color (Album Version)     200
# 3  1540708070796         82                    I Have A Wish     200
# 4  1540006905796        153          Monster (Album Version)     200
# 5  1541064343796         47     Uneasy Hearts Weigh The Most     200
#
#                        ts                                          userAgent  \
# 0 2018-11-02 01:25:34.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 2 2018-11-02 01:30:41.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 3 2018-11-02 01:34:17.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4 2018-11-02 02:42:48.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5 2018-11-02 03:05:57.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#    userId
# 0     101
# 2      83
# 3      83
# 4      66
# 5      48

# %%
user_df = df[['userId','firstName','lastName','gender','level']]
user_df.head()
# Out:
#    userId firstName  lastName gender level
# 0     101    Jayden       Fox      M  free
# 2      83   Stefany     White      F  free
# 3      83   Stefany     White      F  free
# 4      66     Kevin  Arellano      M  free
# 5      48    Marina    Sutton      F  free

# %%
user_df = user_df.drop_duplicates()
user_df.head()
# Out:
#    userId firstName  lastName gender level
# 0     101    Jayden       Fox      M  free
# 2      83   Stefany     White      F  free
# 4      66     Kevin  Arellano      M  free
# 5      48    Marina    Sutton      F  free
# 7      86     Aiden      Hess      M  free

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in t.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    print("Song: %s - Artist: %s - Duration:  %s"%(row.song, row.artist, row.length))
    results = cur.fetchone()
    print(results)
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
    
    #print(songid, artistid)

    #insert songplay record
    #songplay_table_insert = (""" insert into fac_songplay (start_time, user_id, level, song_id, artist_id, session_id, location, user_agent)
    songplay_data = (row['ts'], row['userId'], row['level'], songid, artistid, row['sessionId'], row['location'], row['userAgent'])
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

cur.execute('select count(*) from fac_songplay;')
row = cur.fetchone()
while row:
    print(row)
    row = cur.fetchone()
conn.commit()
# Out:
# Song: Am I High (Feat. Malice) - Artist: N.E.R.D. FEATURING MALICE - Duration:  288.9922
# None
# Song: A Lack Of Color (Album Version) - Artist: Death Cab for Cutie - Duration:  216.42404
# None
# Song: I Have A Wish - Artist: Tracy Gang Pussy - Duration:  221.33506
# None
# Song: Monster (Album Version) - Artist: Skillet - Duration:  178.02404
# None
# Song: Uneasy Hearts Weigh The Most - Artist: Dance Gavin Dance - Duration:  218.46159
# None
# Song: Falta Te Dizer - Artist: Dalto - Duration:  190.40608
# None
# Song: Family Business - Artist: Kanye West - Duration:  278.88281
# None
# Song: Lucky (Album Version) - Artist: Jason Mraz & Colbie Caillat - Duration:  189.6224
# None
# Song: Journey To The Past  (LP Version) - Artist: Liz Callaway - Duration:  175.43791
# None
# Song: Everything I Try to Do_ Nothing Seems to Turn Out Right - Artist: The Decemberists - Duration:  242.59873
# None
# Song: Impossible - Artist: Christina Aguilera - Duration:  254.48444
# None
# Song: Secrets - Artist: OneRepublic - Duration:  224.67873
# None
# Song: Wild World - Artist: Cat Stevens - Duration:  200.202
# None
# Song: World Keeps Turning - Artist: Brett Dennen - Duration:  179.66975
# None
# Song: Greed - Artist: Godsmack - Duration:  208.24771
# None
# Song: Swing Javanaise - Artist: Anis - Duration:  246.59546
# None
# Song: Ed Ero Contentissimo - Artist: Tiziano Ferro - Duration:  251.42812
# None
# Song: Ship Inside A Bottle - Artist: Kylie Auldist - Duration:  265.92608
# None
# Song: The Cut - Artist: Benga - Duration:  286.17098
# None
# Song: Ride A White Swan - Artist: T. Rex - Duration:  132.85832
# None
# Song: Mirando a Las Muchachas - Artist: Mexican Institute of Sound - Duration:  278.04689
# None
# Song: Clouds (Of Color Bright Album Version) - Artist: Velour 100 - Duration:  202.29179
# None
# Song: Riberonzinha - Artist: Maria de Barros - Duration:  276.29669
# None
# Song: Big Blue Note - Artist: Toby Keith - Duration:  177.162
# None
# Song: Naked - Artist: Marques Houston - Duration:  264.98567
# None
# Song: In All This Revelation - Artist: Commit Suicide - Duration:  105.482
# None
# Song: Bottom of a Bottle (Explicit Album Version) - Artist: Smile Empty Soul - Duration:  218.61832
# None
# Song: Wake Up Alone - Artist: Amy Winehouse - Duration:  221.1522
# None
# Song: Sisterfucker (part Ii) - Artist: Eyehategod - Duration:  155.66322
# None
# Song: Dekh Le - Artist: Sunidhi Chauhan / Anu Malik / Jatin Sharma - Duration:  319.32036
# None
# Song: Little Girl Lies (2001 Digital Remaster) - Artist: Blondie - Duration:  127.73832
# None
# Song: Got Me - Artist: She & Him - Duration:  167.83628
# None
# Song: The Lengths - Artist: The Black Keys - Duration:  294.76526
# None
# Song: Eye Of The Tiger - Artist: Survivor - Duration:  245.36771
# None
# Song: I Miss You - Artist: Conya Doss - Duration:  317.98812
# None
# Song: Little April Shower - Artist: Disney Studio Chorus - Duration:  234.84036
# None
# Song: Stillness Is The Move - Artist: Dirty Projectors - Duration:  319.63383
# None
# Song: From Left To Right - Artist: Boom Bip - Duration:  330.16118
# None
# Song: Shelter From The Rain - Artist: Avantasia - Duration:  368.97914
# None
# Song: North Sea Storm (Live) - Artist: Amon Amarth - Duration:  312.29342
# None
# Song: BedRock (Radio Edit) (feat.Lloyd) - Artist: Young Money featuring Lloyd - Duration:  196.33587
# None
# Song: Anti-Everything - Artist: Breakbeat Era - Duration:  326.32118
# None
# Song: Airplanes - Artist: Local Natives - Duration:  237.92281
# None
# Song: Awkward Game - Artist: Gabriella Cilmi - Duration:  207.38567
# None
# Song: Knights - Artist: Minus The Bear - Duration:  219.76771
# None
# Song: No Hay Nadie Como TÃÂº - Artist: Calle 13 Featuring CafÃÂ© Tacuba - Duration:  293.32853
# None
# Song: Fuck Kitty - Artist: Frumpies - Duration:  134.47791
# None
# Song: Barbershop - Artist: D-12 - Duration:  261.40689
# None
# Song: Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto - Artist: Emil Gilels/Orchestre de la SociÃÂ©tÃÂ© des Concerts du Conservatoire/AndrÃÂ© Cluytens - Duration:  375.19628
# None
# Song: Fixin to Thrill - Artist: Dragonette - Duration:  246.49098
# None
# Song: The Western World - Artist: Pennywise - Duration:  188.26404
# None
# Song: Flashing Lights - Artist: Kanye West - Duration:  238.52363
# None
# Song: Waiting for a Train [Single Mix] - Artist: Flash And The Pan - Duration:  224.65261
# None
# Song: New Theory - Artist: Washed Out - Duration:  168.6722
# None
# Song: I Kissed A Girl - Artist: Katy Perry - Duration:  179.40853
# None
# Song: Miss Murder - Artist: AFI - Duration:  198.97424
# None
# Song: Forever - Artist: Drake / Kanye West / Lil Wayne / Eminem - Duration:  357.66812
# None
# Song: 16 Candles - Artist: The Crests - Duration:  182.88281
# None
# Song: Come As You Are - Artist: Nirvana - Duration:  219.08853
# None
# Song: Dragon Pie - Artist: Knights Of The Abyss - Duration:  205.66159
# None
# Song: Honest Expression - Artist: Binary Star - Duration:  300.19873
# None
# Song: Whose Authority - Artist: Nada Surf - Duration:  181.08036
# None
# Song: Beyond Time (Ambient Mix) - Artist: Blank & Jones - Duration:  310.15138
# None
# Song: By Darkness Enslaved - Artist: Carnifex - Duration:  219.89832
# None
# Song: I Am The Walrus - Artist: Bono / Secret Machines - Duration:  285.43955
# None
# Song: The View - Artist: Broadcast 2000 - Duration:  198.84363
# None
# Song: Where Is My Mind? - Artist: Pixies - Duration:  229.3024
# None
# Song: Holy Roller Novocaine - Artist: Kings Of Leon - Duration:  242.99057
# None
# Song: You Know I'm No Good - Artist: Arctic Monkeys - Duration:  221.85751
# None
# Song: ReprÃÂ©sente - Artist: Alliance Ethnik - Duration:  252.21179
# None
# Song: Coma - Artist: Apocalyptica - Duration:  409.86077
# None
# Song: Lil Mama - Artist: Big Tymers - Duration:  256.15628
# None
# Song: Whiskey - Artist: Pat Green - Duration:  295.33995
# None
# Song: No Surprise - Artist: Daughtry - Duration:  249.91302
# None
# Song: Playground Love - Artist: Air - Duration:  212.21832
# None
# Song: Ain't Misbehavin - Artist: Sam Cooke - Duration:  122.04363
# None
# Song: Deep Enough - Artist: Live - Duration:  203.28444
# None
# Song: Summerland - Artist: Everclear - Duration:  222.61506
# None
# Song: Down To The River To Pray - Artist: Alison Krauss / Union Station - Duration:  129.67138
# None
# Song: Move Along - Artist: The All-American Rejects - Duration:  239.22893
# None
# Song: XRDS - Artist: Covenant - Duration:  300.19873
# None
# Song: Liquid Confidence - Artist: You Me At Six - Duration:  191.13751
# None
# Song: Everything Is Alright (Album Version) - Artist: Motion City Soundtrack - Duration:  206.34077
# None
# Song: Something To Believe In - Artist: FM Static - Duration:  169.84771
# None
# Song: Kingdom - Artist: Dave Gahan - Duration:  272.92689
# None
# Song: Mama Said - Artist: Metallica - Duration:  319.73832
# None
# Song: Sylvia's Mother - Artist: Dr. Hook - Duration:  229.77261
# None
# Song: Diferente - Artist: Gotan Project - Duration:  321.30567
# None
# Song: Play On - Artist: Carrie Underwood - Duration:  221.3873
# None
# Song: I.D. - Artist: Ut - Duration:  313.86077
# None
# Song: Drop The World - Artist: Lil Wayne / Eminem - Duration:  229.58975
# None
# Song: For Your Pleasure - Artist: Damage - Duration:  263.18322
# None
# Song: De SÃÂ£o Paulo ÃÂ BelÃÂ©m - Artist: Rionegro / SolimÃÂµes - Duration:  280.92036
# None
# Song: Outfit - Artist: Drive-By Truckers - Duration:  246.22975
# None
# Song: Smoking Cigarettes (LP Version) - Artist: Tweet - Duration:  256.39138
# None
# Song: Steven's Last Night In Town - Artist: Ben Folds Five - Duration:  207.882
# None
# Song: Lies - Artist: Glen Hansard - Duration:  239.59465
# None
# Song: Dos (LP Version) - Artist: Chevelle - Duration:  389.85098
# None
# Song: Make Love To Your Mind - Artist: Bill Withers - Duration:  383.73832
# None
# Song: Salvapantallas - Artist: Jorge Drexler - Duration:  272.14322
# None
# Song: How Am I Supposed To Live Without You - Artist: Michael Bolton - Duration:  255.65995
# None
# Song: Marianas - Artist: The Mercury Program - Duration:  449.12281
# None
# Song: The Seventh Stranger - Artist: Duran Duran - Duration:  321.88036
# None
# Song: Meddle - Artist: Little Boots - Duration:  195.94404
# None
# Song: Glory Days To Come - Artist: Johnossi - Duration:  174.2624
# None
# Song: Undo - Artist: BjÃÂ¶rk - Duration:  348.57751
# None
# Song: Hey Mama - Artist: Black Eyed Peas - Duration:  226.37669
# None
# Song: Find You Waiting - Artist: DecembeRadio - Duration:  249.62567
# None
# Song: 1009 - Artist: Bonobo - Duration:  270.41914
# None
# Song: Canada - Artist: Five Iron Frenzy - Duration:  236.09424
# None
# Song: The Sea - Artist: Morcheeba - Duration:  347.71546
# None
# Song: All My Mistakes (US4BW0700133) - Artist: The Avett Brothers - Duration:  307.9571
# None
# Song: Children - Artist: Dave Darell - Duration:  217.33832
# None
# Song: Talk To Her - Artist: Priestess - Duration:  190.45832
# None
# Song: I'm Sleeping In A Submarine - Artist: Arcade Fire - Duration:  169.19465
# None
# Song: Crescendolls - Artist: Daft Punk - Duration:  211.69587
# None
# Song: When In Rome - Artist: Nickel Creek - Duration:  255.13751
# None
# Song: Footprints - Artist: Squeeze - Duration:  229.56363
# None
# Song: Sweet Hitch-Hiker - Artist: Creedence Clearwater Revival - Duration:  175.80363
# None
# Song: Love Like Crazy (Extended Mix) - Artist: Kierra Sheard - Duration:  299.02322
# None
# Song: Comes And Goes ( In Waves ) - Artist: Greg Laswell - Duration:  251.08853
# None
# Song: Mercy:The Laundromat - Artist: Pavement - Duration:  99.16036
# None
# Song: Courtesy Call (Explicit) - Artist: Sixx A.M. - Duration:  280.58077
# None
# Song: I'm Your Man - Artist: Leonard Cohen - Duration:  267.67628
# None
# Song: The Wild Hunt - Artist: The Tallest Man On Earth - Duration:  203.62404
# None
# Song: Teenagers (Album Version) - Artist: My Chemical Romance - Duration:  161.90649
# None
# Song: After Laughter (Comes Tears) (LP Version) - Artist: Wendy Rene - Duration:  182.46485
# None
# Song: Country Road - Artist: Jack Johnson / Paula Fuga - Duration:  178.33751
# None
# Song: Invalid - Artist: Tub Ring - Duration:  233.69098
# None
# Song: BND - Artist: No Doubt - Duration:  44.93016
# None
# Song: I Kissed A Girl - Artist: Katy Perry - Duration:  179.40853
# None
# Song: Ghost - Artist: Neutral Milk Hotel - Duration:  248.37179
# None
# Song: You're The One - Artist: Dwight Yoakam - Duration:  239.3073
# None
# Song: On Green Dolphin Street (Medley) (1999 Digital Remaster) - Artist: Ella Fitzgerald - Duration:  427.15383
# None
# Song: Van Comp - Artist: Tony Rohr - Duration:  403.09506
# None
# Song: Divers - Artist: Braid - Duration:  222.74567
# None
# Song: Hello Little Girl - Artist: Fourmost - Duration:  113.6322
# None
# Song: Hormigas - Artist: Catupecu Machu - Duration:  212.32281
# None
# Song: Weathered - Artist: Creed - Duration:  329.87383
# None
# Song: Chi Mai (El Profesional) - Artist: Ennio Morricone - Duration:  215.01342
# None
# Song: Keep On Keepin' On - Artist: Down To The Bone - Duration:  333.76608
# None
# Song: Greece 2000 - Artist: Three Drives - Duration:  411.6371
# None
# Song: Kilometer - Artist: Sebastien Tellier - Duration:  377.73016
# None
# Song: Catch You Baby (Steve Pitron & Max Sanna Radio Edit) - Artist: Lonnie Gordon - Duration:  181.21098
# None
# Song: Fireflies - Artist: Charttraxx Karaoke - Duration:  225.17506
# None
# Song: NiÃÂ±o Soldado - Artist: Ska-P - Duration:  220.21179
# None
# Song: You're The One - Artist: Dwight Yoakam - Duration:  239.3073
# None
# Song: Pop Is Dead - Artist: Radiohead - Duration:  130.82077
# None
# Song: The Mountains Of Navaho - Artist: Scouting for Girls - Duration:  201.1424
# None
# Song: SinceritÃÂ© Et Jalousie - Artist: Alliance Ethnik - Duration:  195.94404
# None
# Song: Ova Da Wudz - Artist: OutKast - Duration:  227.52608
# None
# Song: Uhn Tiss Uhn Tiss Uhn Tiss - Artist: Bloodhound Gang - Duration:  260.20526
# None
# Song: Adios - Artist: Rammstein - Duration:  228.46649
# None
# Song: Pop Corn - Artist: Gershon Kingsley - Duration:  146.57261
# None
# Song: Strasbourg - Artist: The Rakes - Duration:  150.59546
# None
# (155,)

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
